# %%
#importing libraries
import numpy as np
import cv2
import mahotas
from google.colab.patches import cv2_imshow
#reading image
image = cv2.imread("ppp")
#converting image to grayscale
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#applying gaussian blur
blurred = cv2.GaussianBlur(image, (5,5), 0)
cv2_imshow(image)
#Otsu thresholding
T = mahotas.thresholding.otsu(blurred)
thresh = image.copy()
thresh[thresh > T] = 255
thresh[thresh < 255] = 0
thresh = cv2.bitwise_not(thresh)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FD5AE8D75D0>
# <PIL.Image.Image image mode=L size=400x400 at 0x7FD5AE8D7510>

# %%
# !pip install mahotas
# Out:
# Collecting mahotas
#   Downloading https://files.pythonhosted.org/packages/19/ad/553b246b0a35dccc3ed58dc8889a67124bf5ab858e9c6b7255d56086e70c/mahotas-1.4.11-cp37-cp37m-manylinux2010_x86_64.whl (5.7MB)
#      |████████████████████████████████| 5.7MB 7.0MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.19.5)
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.11
