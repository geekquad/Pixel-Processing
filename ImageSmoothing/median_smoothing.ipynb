# %% [markdown]
# ###

# %%
import cv2
from matplotlib import pyplot as plot
import numpy as nm

# %%
img =cv2.imread("house.jfif")
plot.imshow(img)
plot.title("Original Image")
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
median_smoothing_img=cv2.medianBlur(img,5)

# %%
plot.imshow(median_smoothing_img)
plot.title("Median Smoothing")
# Out:
# Text(0.5, 1.0, 'Median Smoothing')
