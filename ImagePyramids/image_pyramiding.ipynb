# %% [markdown]
# # Image Pyramiding

# %%
import cv2
from matplotlib import pyplot as plot
import numpy as nm

# %%
img =cv2.imread("apple.jpg")[:,:,::-1]
plot.imshow(img)
plot.title("Original Image")
# Out:
# Text(0.5, 1.0, 'Original Image')

# %% [markdown]
# #### Dimension Of Orignal Image

# %%
print(img.shape)
# Out:
# (500, 500, 3)

# %% [markdown]
# ### Increasing Size

# %%
larger_img=cv2.pyrUp(img)
plot.imshow(Small)

# %% [markdown]
# #### Dimension after using pyrUp

# %%
print(larger_img.shape)
# Out:
# (1000, 1000, 3)

# %% [markdown]
# ### Decreasing Size

# %%
smaller_img=cv2.pyrDown(img)
plot.imshow(smaller_img)

# %% [markdown]
# #### Dimension after using pyrDown

# %%
print(smaller_img.shape)
# Out:
# (250, 250, 3)
