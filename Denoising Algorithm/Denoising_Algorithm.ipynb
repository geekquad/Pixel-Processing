# %%
'''
    Denoising Algorithm
'''
#Importing openCV library
import cv2 as cv
from google.colab.patches import cv2_imshow

#Taking path of input from the user
path=input("Enter the path of image: ")
img=cv.imread(path)
img=cv.resize(img,(600,600))  #resizing the image

#Display the input image
cv2_imshow(img)

#Excueting the Denoising Algorithm
dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)
cv2_imshow(dst)
# Out:
# Enter the path of image: /content/Input.png
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F4094A2B950>
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F4094A1B450>
