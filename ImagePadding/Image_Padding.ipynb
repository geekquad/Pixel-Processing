# %%
import cv2 

import numpy as np

from matplotlib import pyplot as plt

from google.colab.patches import cv2_imshow

BLUE = [255,0,0]

img1 = cv2.imread('ppp')

cv2_imshow(img1)

constant= cv2.copyMakeBorder(img1,10,10,10,10,cv.BORDER_CONSTANT,value=BLUE)


cv2_imshow(constant)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F3EB8993150>
# <PIL.Image.Image image mode=RGB size=420x420 at 0x7F3EB8993610>
