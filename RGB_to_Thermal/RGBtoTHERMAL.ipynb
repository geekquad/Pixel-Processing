# %% [markdown]
# <a href="https://colab.research.google.com/github/geekquad/rgb-to-thermal/blob/master/RGBtoTHERMAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

image = cv2.imread('/content/drive/My Drive/butterfly.jpg')

plt.imshow(image)
plt.show()

# %%
# %matplotlib inline
plt.imshow(cv2.applyColorMap(image, cv2.COLOR_RGB2BGR))
