# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image1 = cv2.imread(r'circle1.jpg')
plt.imshow(image1)
plt.show()

# %%
image2 = cv2.imread(r'pattern1.jpg')
plt.imshow(image2)
plt.show()

# %%
subImage = cv2.subtract(image1,image2)

# %%
cv2.imshow('subtracted image',subImage)
plt.imshow(subImage)
plt.show()

# %%
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
